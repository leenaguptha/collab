# %% [markdown]
# <a href="https://colab.research.google.com/github/leenaguptha/collab/blob/main/Basics_of_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***DATA MANIPULATION AND ANALYSIS USING PANDAS***

# %% [markdown]
# In Machine learning we need dataset to operate the algorithm, and dataset may be of training and testing data.
#
# When we are looking for dataset from various platforms and regions, we will be getting the dataset that consists of NAN, NULL and various other forms.
#
# So it is important to modify and clean the data for better insights.
#
# PANDAS is a famous library of python which helps us in giving out the accurate insights of the data.

# %% [markdown]
# ** Before moving forward, ensure that Pandas is installed in your system**

# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/natezhang123/social-anxiety-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: leenavemula
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/natezhang123/social-anxiety-dataset

# %%
#Use this to install pandas

# %%
pip install pandas

# %%
#Importing of pandas library
import pandas as pd

# %% [markdown]
# Basic operations using pandas

# %%
#Creating a new DataFrame
df1 = pd.DataFrame({'A':[1,2,3,4],'B':['hello','how','are','you']})

# %%
df1
# Out:
#    A      B
# 0  1  hello
# 1  2    how
# 2  3    are
# 3  4    you

# %% [markdown]
# Data Frame is being created, where [ A,B ] are the names of columns

# %%
df1.columns
# Out:
# Index(['A', 'B'], dtype='object')

# %% [markdown]
# *** Loading of the data ***

# %%
import pandas as pd
df = pd.read_csv("/content/social-anxiety-dataset/enhanced_anxiety_dataset.csv")

# %% [markdown]
# *** Data Exploration ***

# %%
df.head()

#View top rows
# Out:
#    Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0   29  Female     Artist          6.0                           2.7
# 1   46   Other      Nurse          6.2                           5.7
# 2   64    Male      Other          5.0                           3.7
# 3   20  Female  Scientist          5.8                           2.8
# 4   49  Female      Other          8.2                           2.3
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                       181                                 10     Yes
# 1                       200                                  8     Yes
# 2                       117                                  4      No
# 3                       360                                  6     Yes
# 4                       247                                  4     Yes
#
#   Family History of Anxiety  Stress Level (1-10)  Heart Rate (bpm)  \
# ...

# %%
df.tail()

#View bottom rows
# Out:
#        Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 10995   23  Female   Engineer          6.1                           3.1
# 10996   50   Other    Teacher          6.6                           3.6
# 10997   29    Male      Nurse          6.7                           6.9
# 10998   53   Other     Artist          5.7                           2.7
# 10999   56   Other    Teacher          6.1                           1.1
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 10995                       566                                  9     Yes
# 10996                        64                                 17     Yes
# 10997                       159                                 14      No
# 10998                       248                                  8      No
# 10999                       205                                 11      No
#
#       Family History of Anxiety  Stress Level (1-10)  Heart Rate (bpm)  \
# ...

# %%
df.head(300)

#view first 300 rows
# Out:
#      Age  Gender  Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0     29  Female      Artist          6.0                           2.7
# 1     46   Other       Nurse          6.2                           5.7
# 2     64    Male       Other          5.0                           3.7
# 3     20  Female   Scientist          5.8                           2.8
# 4     49  Female       Other          8.2                           2.3
# ..   ...     ...         ...          ...                           ...
# 295   22    Male      Lawyer          3.9                           0.8
# 296   38    Male     Athlete          5.2                           0.3
# 297   20  Female     Teacher          7.3                           0.2
# 298   22  Female  Freelancer          4.5                           1.2
# 299   34   Other  Freelancer          7.4                           1.4
#
#      Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# ...

# %%
df.describe()

#Statistics Summary
# Out:
#                 Age   Sleep Hours  Physical Activity (hrs/week)  \
# count  11000.000000  11000.000000                  11000.000000
# mean      40.241727      6.650691                      2.942136
# std       13.236140      1.227509                      1.827825
# min       18.000000      2.300000                      0.000000
# 25%       29.000000      5.900000                      1.500000
# 50%       40.000000      6.700000                      2.800000
# 75%       51.000000      7.500000                      4.200000
# max       64.000000     11.300000                     10.100000
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week)  \
# count              11000.000000                       11000.000000
# mean                 286.090000                           9.701636
# std                  144.813157                           5.689713
# min                    0.000000                           0.000000
# ...

# %%
df.dtypes

#Kind of data present in each column
# Out:
# Age                                    int64
# Gender                                object
# Occupation                            object
# Sleep Hours                          float64
# Physical Activity (hrs/week)         float64
# Caffeine Intake (mg/day)               int64
# Alcohol Consumption (drinks/week)      int64
# Smoking                               object
# Family History of Anxiety             object
# Stress Level (1-10)                    int64
# Heart Rate (bpm)                       int64
# Breathing Rate (breaths/min)           int64
# Sweating Level (1-5)                   int64
# Dizziness                             object
# Medication                            object
# Therapy Sessions (per month)           int64
# Recent Major Life Event               object
# Diet Quality (1-10)                    int64
# Anxiety Level (1-10)                 float64
# dtype: object

# %%
df.isnull().sum()

#Finding out the missing values count in each and every column
# Out:
# Age                                  0
# Gender                               0
# Occupation                           0
# Sleep Hours                          0
# Physical Activity (hrs/week)         0
# Caffeine Intake (mg/day)             0
# Alcohol Consumption (drinks/week)    0
# Smoking                              0
# Family History of Anxiety            0
# Stress Level (1-10)                  0
# Heart Rate (bpm)                     0
# Breathing Rate (breaths/min)         0
# Sweating Level (1-5)                 0
# Dizziness                            0
# Medication                           0
# Therapy Sessions (per month)         0
# Recent Major Life Event              0
# Diet Quality (1-10)                  0
# Anxiety Level (1-10)                 0
# dtype: int64

# %% [markdown]
# *** Data Selection ***

# %%
df['Age']

#select a particular column --->>> df["name_of_column"]
# Out:
# 0        29
# 1        46
# 2        64
# 3        20
# 4        49
#          ..
# 10995    23
# 10996    50
# 10997    29
# 10998    53
# 10999    56
# Name: Age, Length: 11000, dtype: int64

# %%
df[['Age','Physical Activity (hrs/week)']]

#Select multiple columns --->>> df[["column_1","column_2"]]
# Out:
#        Age  Physical Activity (hrs/week)
# 0       29                           2.7
# 1       46                           5.7
# 2       64                           3.7
# 3       20                           2.8
# 4       49                           2.3
# ...    ...                           ...
# 10995   23                           3.1
# 10996   50                           3.6
# 10997   29                           6.9
# 10998   53                           2.7
# 10999   56                           1.1
#
# [11000 rows x 2 columns]

# %%
v = df[['Age','Caffeine Intake (mg/day)','Smoking']]

# %%
v
# Out:
#        Age  Caffeine Intake (mg/day) Smoking
# 0       29                       181     Yes
# 1       46                       200     Yes
# 2       64                       117      No
# 3       20                       360     Yes
# 4       49                       247     Yes
# ...    ...                       ...     ...
# 10995   23                       566     Yes
# 10996   50                        64     Yes
# 10997   29                       159      No
# 10998   53                       248      No
# 10999   56                       205      No
#
# [11000 rows x 3 columns]

# %%
type(v)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Sleep Hours'][1:100:3]

#Selecting rows with the help of indexing --->>> df.iloc[start_index : End_index : Jump]
# Out:
# 1     6.2
# 4     8.2
# 7     6.3
# 10    8.0
# 13    7.5
# 16    6.7
# 19    5.0
# 22    4.5
# 25    4.0
# 28    5.6
# 31    4.6
# 34    7.0
# 37    8.5
# 40    7.9
# 43    6.4
# 46    5.9
# 49    5.0
# 52    6.5
# 55    5.0
# 58    6.4
# 61    5.8
# 64    8.1
# 67    6.4
# 70    6.8
# 73    8.5
# 76    7.4
# 79    6.4
# 82    6.1
# 85    5.5
# 88    7.0
# 91    5.6
# 94    7.1
# 97    5.5
# Name: Sleep Hours, dtype: float64

# %%
df[['Sleep Hours','Age']][1:50:4]
# Out:
#     Sleep Hours  Age
# 1           6.2   46
# 5           6.4   53
# 9           5.1   59
# 13          7.5   31
# 17          6.7   61
# 21          8.2   41
# 25          4.0   40
# 29          2.6   32
# 33          5.6   44
# 37          8.5   26
# 41          7.6   24
# 45          6.9   36
# 49          5.0   27

# %%
df.columns

#view of all the columns present in the dataset
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Sleep Hours',
#        'Physical Activity (hrs/week)', 'Caffeine Intake (mg/day)',
#        'Alcohol Consumption (drinks/week)', 'Smoking',
#        'Family History of Anxiety', 'Stress Level (1-10)', 'Heart Rate (bpm)',
#        'Breathing Rate (breaths/min)', 'Sweating Level (1-5)', 'Dizziness',
#        'Medication', 'Therapy Sessions (per month)', 'Recent Major Life Event',
#        'Diet Quality (1-10)', 'Anxiety Level (1-10)'],
#       dtype='object')

# %%
df.iloc[1:5]

#Here we are selecting rows with the help of indexing

# iloc [1:5] ---->> Start from index 1 and go till index 4 (exclude last index from condition same like of indexing in any coding language)
# Out:
#    Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 1   46   Other      Nurse          6.2                           5.7
# 2   64    Male      Other          5.0                           3.7
# 3   20  Female  Scientist          5.8                           2.8
# 4   49  Female      Other          8.2                           2.3
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 1                       200                                  8     Yes
# 2                       117                                  4      No
# 3                       360                                  6     Yes
# 4                       247                                  4     Yes
#
#   Family History of Anxiety  Stress Level (1-10)  Heart Rate (bpm)  \
# 1                       Yes                    1                62
# 2                       Yes                    1                91
# ...

# %%
df.iloc[0:5]

#start from 0th index and go till 4th index
# Out:
#    Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0   29  Female     Artist          6.0                           2.7
# 1   46   Other      Nurse          6.2                           5.7
# 2   64    Male      Other          5.0                           3.7
# 3   20  Female  Scientist          5.8                           2.8
# 4   49  Female      Other          8.2                           2.3
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                       181                                 10     Yes
# 1                       200                                  8     Yes
# 2                       117                                  4      No
# 3                       360                                  6     Yes
# 4                       247                                  4     Yes
#
#   Family History of Anxiety  Stress Level (1-10)  Heart Rate (bpm)  \
# ...

# %%
df['Age']>10

#Checking the condition for a column --->>> df["column_name"]condition
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10995    True
# 10996    True
# 10997    True
# 10998    True
# 10999    True
# Name: Age, Length: 11000, dtype: bool

# %%
df[df['Age']>10]

#Accesing of entire rows with the condition for particular column

# df[df['column_name']condition]
# Out:
#        Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0       29  Female     Artist          6.0                           2.7
# 1       46   Other      Nurse          6.2                           5.7
# 2       64    Male      Other          5.0                           3.7
# 3       20  Female  Scientist          5.8                           2.8
# 4       49  Female      Other          8.2                           2.3
# ...    ...     ...        ...          ...                           ...
# 10995   23  Female   Engineer          6.1                           3.1
# 10996   50   Other    Teacher          6.6                           3.6
# 10997   29    Male      Nurse          6.7                           6.9
# 10998   53   Other     Artist          5.7                           2.7
# 10999   56   Other    Teacher          6.1                           1.1
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# ...

# %% [markdown]
# *** Data Manipulation ***

# %%
#Adding of new column :


df['New_col'] = df['Stress Level (1-10)'] + df['Heart Rate (bpm)']

# %%
df
# Out:
#        How many years  Gender Occupation  Sleep Hours  \
# 0                  29  Female     Artist          6.0
# 1                  46   Other      Nurse          6.2
# 2                  64    Male      Other          5.0
# 3                  20  Female  Scientist          5.8
# 4                  49  Female      Other          8.2
# ...               ...     ...        ...          ...
# 10995              23  Female   Engineer          6.1
# 10996              50   Other    Teacher          6.6
# 10997              29    Male      Nurse          6.7
# 10998              53   Other     Artist          5.7
# 10999              56   Other    Teacher          6.1
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0                               2.7                       181
# 1                               5.7                       200
# 2                               3.7                       117
# 3                               2.8                       360
# ...

# %%
df['new_col'] = df['Sleep Hours'] + df['Physical Activity (hrs/week)']

# %%
df
# Out:
#        How many years  Gender Occupation  Sleep Hours  \
# 0                  29  Female     Artist          6.0
# 1                  46   Other      Nurse          6.2
# 2                  64    Male      Other          5.0
# 3                  20  Female  Scientist          5.8
# 4                  49  Female      Other          8.2
# ...               ...     ...        ...          ...
# 10995              23  Female   Engineer          6.1
# 10996              50   Other    Teacher          6.6
# 10997              29    Male      Nurse          6.7
# 10998              53   Other     Artist          5.7
# 10999              56   Other    Teacher          6.1
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0                               2.7                       181
# 1                               5.7                       200
# 2                               3.7                       117
# 3                               2.8                       360
# ...

# %% [markdown]
# We are getting errors in the above 2cases, this is because we are trying to add o different data types. Which is not possible.

# %%
df['new_col'] = df['Age'] + 10

# %%
df
# Out:
#        How many years  Gender Occupation  Sleep Hours  \
# 0                  29  Female     Artist          6.0
# 1                  46   Other      Nurse          6.2
# 2                  64    Male      Other          5.0
# 3                  20  Female  Scientist          5.8
# 4                  49  Female      Other          8.2
# ...               ...     ...        ...          ...
# 10995              23  Female   Engineer          6.1
# 10996              50   Other    Teacher          6.6
# 10997              29    Male      Nurse          6.7
# 10998              53   Other     Artist          5.7
# 10999              56   Other    Teacher          6.1
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0                               2.7                       181
# 1                               5.7                       200
# 2                               3.7                       117
# 3                               2.8                       360
# ...

# %%
df['new_col2'] = df['How many years'] + df['Caffeine Intake (mg/day)']

# %%
df
# Out:
#        How many years  Gender Occupation  Sleep Hours  \
# 0                  29  Female     Artist          6.0
# 1                  46   Other      Nurse          6.2
# 2                  64    Male      Other          5.0
# 3                  20  Female  Scientist          5.8
# 4                  49  Female      Other          8.2
# ...               ...     ...        ...          ...
# 10995              23  Female   Engineer          6.1
# 10996              50   Other    Teacher          6.6
# 10997              29    Male      Nurse          6.7
# 10998              53   Other     Artist          5.7
# 10999              56   Other    Teacher          6.1
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0                               2.7                       181
# 1                               5.7                       200
# 2                               3.7                       117
# 3                               2.8                       360
# ...

# %%
df.dtypes
# Out:
# Age                                    int64
# Gender                                object
# Occupation                            object
# Sleep Hours                          float64
# Physical Activity (hrs/week)         float64
# Caffeine Intake (mg/day)               int64
# Alcohol Consumption (drinks/week)      int64
# Smoking                               object
# Family History of Anxiety             object
# Stress Level (1-10)                    int64
# Heart Rate (bpm)                       int64
# Breathing Rate (breaths/min)           int64
# Sweating Level (1-5)                   int64
# Dizziness                             object
# Medication                            object
# Therapy Sessions (per month)           int64
# Recent Major Life Event               object
# Diet Quality (1-10)                    int64
# Anxiety Level (1-10)                 float64
# new_col                                int64
# dtype: object

# %% [markdown]
# We can find that two different columns are added

# %%
# Now we ae deleting the newly added columns

df = df.drop(['new_col','new_col2'],axis=1)

# %%
df
# Out:
#        How many years  Gender Occupation  Sleep Hours  \
# 0                  29  Female     Artist          6.0
# 1                  46   Other      Nurse          6.2
# 2                  64    Male      Other          5.0
# 3                  20  Female  Scientist          5.8
# 4                  49  Female      Other          8.2
# ...               ...     ...        ...          ...
# 10995              23  Female   Engineer          6.1
# 10996              50   Other    Teacher          6.6
# 10997              29    Male      Nurse          6.7
# 10998              53   Other     Artist          5.7
# 10999              56   Other    Teacher          6.1
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0                               2.7                       181
# 1                               5.7                       200
# 2                               3.7                       117
# 3                               2.8                       360
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Sleep Hours',
#        'Physical Activity (hrs/week)', 'Caffeine Intake (mg/day)',
#        'Alcohol Consumption (drinks/week)', 'Smoking',
#        'Family History of Anxiety', 'Stress Level (1-10)', 'Heart Rate (bpm)',
#        'Breathing Rate (breaths/min)', 'Sweating Level (1-5)', 'Dizziness',
#        'Medication', 'Therapy Sessions (per month)', 'Recent Major Life Event',
#        'Diet Quality (1-10)', 'Anxiety Level (1-10)', 'new_col'],
#       dtype='object')

# %%
df.shape
# Out:
# (11000, 20)

# %%
#Renaming of the columns

df = df.rename(columns={'Age':'How many years'})

# %%
df
# Out:
#        How many years  Gender Occupation  Sleep Hours  \
# 0                  29  Female     Artist          6.0
# 1                  46   Other      Nurse          6.2
# 2                  64    Male      Other          5.0
# 3                  20  Female  Scientist          5.8
# 4                  49  Female      Other          8.2
# ...               ...     ...        ...          ...
# 10995              23  Female   Engineer          6.1
# 10996              50   Other    Teacher          6.6
# 10997              29    Male      Nurse          6.7
# 10998              53   Other     Artist          5.7
# 10999              56   Other    Teacher          6.1
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0                               2.7                       181
# 1                               5.7                       200
# 2                               3.7                       117
# 3                               2.8                       360
# ...

# %%
df['How many years'][0:4]
# Out:
# 0    29
# 1    46
# 2    64
# 3    20
# Name: How many years, dtype: int64
